# %%
import pandas as pd
df1=pd.read_csv('https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/refs/heads/master/MoviesOnStreamingPlatforms_updated.csv')
df1
# Out:
#        Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741                  The Poof Point  2001   7+   4.7
# 16741       16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744                In Beaver Valley  1950  NaN   NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes',
#        'Netflix', 'Hulu', 'Prime Video', 'Disney+', 'Type', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16130 non-null  object
#  16  Runtime          16152 non-null  float64
# ...

# %%
df1.describe()
# Out:
#          Unnamed: 0            ID          Year          IMDb       Netflix  \
# count  16744.000000  16744.000000  16744.000000  16173.000000  16744.000000
# mean    8371.500000   8372.500000   2003.014035      5.902751      0.212613
# std     4833.720789   4833.720789     20.674321      1.347867      0.409169
# min        0.000000      1.000000   1902.000000      0.000000      0.000000
# 25%     4185.750000   4186.750000   2000.000000      5.100000      0.000000
# 50%     8371.500000   8372.500000   2012.000000      6.100000      0.000000
# 75%    12557.250000  12558.250000   2016.000000      6.900000      0.000000
# max    16743.000000  16744.000000   2020.000000      9.300000      1.000000
#
#                Hulu   Prime Video       Disney+     Type       Runtime
# count  16744.000000  16744.000000  16744.000000  16744.0  16152.000000
# mean       0.053930      0.737817      0.033684      0.0     93.413447
# std        0.225886      0.439835      0.180419      0.0     28.219222
# ...

# %%
df1.describe(percentiles=[0.25,0.35])
# Out:
#          Unnamed: 0            ID          Year          IMDb       Netflix  \
# count  16744.000000  16744.000000  16744.000000  16173.000000  16744.000000
# mean    8371.500000   8372.500000   2003.014035      5.902751      0.212613
# std     4833.720789   4833.720789     20.674321      1.347867      0.409169
# min        0.000000      1.000000   1902.000000      0.000000      0.000000
# 25%     4185.750000   4186.750000   2000.000000      5.100000      0.000000
# 35%     5860.050000   5861.050000   2007.000000      5.500000      0.000000
# 50%     8371.500000   8372.500000   2012.000000      6.100000      0.000000
# max    16743.000000  16744.000000   2020.000000      9.300000      1.000000
#
#                Hulu   Prime Video       Disney+     Type       Runtime
# count  16744.000000  16744.000000  16744.000000  16744.0  16152.000000
# mean       0.053930      0.737817      0.033684      0.0     93.413447
# std        0.225886      0.439835      0.180419      0.0     28.219222
# ...

# %%
df1.describe(include='object')
# Out:
#                    Title   Age Rotten Tomatoes    Directors Genres  \
# count              16744  7354            5158        16018  16469
# unique             16744     5              99        11338   1909
# top     In Beaver Valley   18+            100%  Jay Chapman  Drama
# freq                   1  3474             407           36   1341
#
#               Country Language
# count           16309    16130
# unique           1303     1101
# top     United States  English
# freq             8776    10955

# %%
df1.loc[1,'Age']
# Out:
# '18+'

# %%
df1.iloc[2,2]
# Out:
# 'Avengers: Infinity War'

# %%
df1.head(10)
# Out:
#    Unnamed: 0  ID                              Title  Year  Age  IMDb  \
# 0           0   1                          Inception  2010  13+   8.8
# 1           1   2                         The Matrix  1999  18+   8.7
# 2           2   3             Avengers: Infinity War  2018  13+   8.5
# 3           3   4                 Back to the Future  1985   7+   8.5
# 4           4   5     The Good, the Bad and the Ugly  1966  18+   8.8
# 5           5   6  Spider-Man: Into the Spider-Verse  2018   7+   8.4
# 6           6   7                        The Pianist  2002  18+   8.5
# 7           7   8                   Django Unchained  2012  18+   8.4
# 8           8   9            Raiders of the Lost Ark  1981   7+   8.4
# 9           9  10               Inglourious Basterds  2009  18+   8.3
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# ...

# %%
df1.tail(10)
# Out:
#        Unnamed: 0     ID                                Title  Year  Age  \
# 16734       16734  16735             Sultan And The Rock Star  1980  NaN
# 16735       16735  16736            Secrets of the King Cobra  2010  NaN
# 16736       16736  16737  Winged Seduction: Birds of Paradise  2012  NaN
# 16737       16737  16738                      The Bears and I  1974  all
# 16738       16738  16739         Whispers: An Elephant's Tale  2000  all
# 16739       16739  16740            The Ghosts of Buxley Hall  1980  NaN
# 16740       16740  16741                       The Poof Point  2001   7+
# 16741       16741  16742                Sharks of Lost Island  2013  NaN
# 16742       16742  16743                   Man Among Cheetahs  2017  NaN
# 16743       16743  16744                     In Beaver Valley  1950  NaN
#
#        IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 16734   5.9             NaN        0     0            0        1     0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16130 non-null  object
#  16  Runtime          16152 non-null  float64
# ...

# %%
df1['Age']=df1['Age'].ffill()
df1['Directors']=df1['Directors'].bfill()

# %%
df1['IMDb']=df1['IMDb'].fillna(5.902751)
df1['Runtime']=df1['Runtime'].bfill()

# %%
df1['Genres'].mode()
df1['Country'].mode()
df1['Language'].mode()
# Out:
# 0    English
# Name: Language, dtype: object

# %%
df1['Genres']=df1['Genres'].fillna('Drama')
df1['Country']=df1['Country'].fillna('United States')
df1['Language']=df1['Language'].fillna('English')

# %%
df1=df1.dropna(axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   16744 non-null  int64
#  1   ID           16744 non-null  int64
#  2   Title        16744 non-null  object
#  3   Year         16744 non-null  int64
#  4   Age          16744 non-null  object
#  5   IMDb         16744 non-null  float64
#  6   Netflix      16744 non-null  int64
#  7   Hulu         16744 non-null  int64
#  8   Prime Video  16744 non-null  int64
#  9   Disney+      16744 non-null  int64
#  10  Type         16744 non-null  int64
#  11  Directors    16744 non-null  object
#  12  Genres       16744 non-null  object
#  13  Country      16744 non-null  object
#  14  Language     16744 non-null  object
#  15  Runtime      16744 non-null  float64
# dtypes: float64(2), int64(8), object(6)
# memory usage: 2.0+ MB

# %%
df1
# Out:
#        Unnamed: 0     ID                           Title  Year  Age      IMDb  \
# 0               0      1                       Inception  2010  13+  8.800000
# 1               1      2                      The Matrix  1999  18+  8.700000
# 2               2      3          Avengers: Infinity War  2018  13+  8.500000
# 3               3      4              Back to the Future  1985   7+  8.500000
# 4               4      5  The Good, the Bad and the Ugly  1966  18+  8.800000
# ...           ...    ...                             ...   ...  ...       ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  all  6.200000
# 16740       16740  16741                  The Poof Point  2001   7+  4.700000
# 16741       16741  16742           Sharks of Lost Island  2013   7+  5.700000
# 16742       16742  16743              Man Among Cheetahs  2017   7+  6.600000
# 16743       16743  16744                In Beaver Valley  1950   7+  5.902751
#
# ...

# %%
df1['Runtime']=df1['Runtime'].astype('Int64')
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_24156\2364895914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Runtime']=df1['Runtime'].astype('Int64')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   16744 non-null  int64
#  1   ID           16744 non-null  int64
#  2   Title        16744 non-null  object
#  3   Year         16744 non-null  int64
#  4   Age          16744 non-null  object
#  5   IMDb         16744 non-null  float64
#  6   Netflix      16744 non-null  int64
#  7   Hulu         16744 non-null  int64
#  8   Prime Video  16744 non-null  int64
#  9   Disney+      16744 non-null  int64
#  10  Type         16744 non-null  int64
#  11  Directors    16744 non-null  object
#  12  Genres       16744 non-null  object
#  13  Country      16744 non-null  object
#  14  Language     16744 non-null  object
#  15  Runtime      16744 non-null  Int64
# dtypes: Int64(1), float64(1), int64(8), object(6)
# memory usage: 2.1+ MB
