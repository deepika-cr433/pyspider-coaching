# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/refs/heads/master/titanic.csv")
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
c1=df.columns
print(c1)
i1=df.info()
print(i1)
d1=df.describe()
print(d1)
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'survived'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB
# None
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# ...

# %%
d2=df.describe(include='object')
print(d2)
d3=df.describe(percentiles=[0.1,0.9,0.85,0.45])
print(d3)
# Out:
#                         name   sex    ticket        cabin embarked
# count                   1309  1309      1309          295     1307
# unique                  1307     2       929          186        3
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S
# freq                       2   843        11            6      914
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# mean      2.294882    29.881135     0.498854     0.385027    33.295479
# std       0.837836    14.413500     1.041658     0.865560    51.758668
# min       1.000000     0.166700     0.000000     0.000000     0.000000
# 10%       1.000000    14.000000     0.000000     0.000000     7.567500
# 45%       2.000000    26.000000     0.000000     0.000000    13.000000
# 50%       3.000000    28.000000     0.000000     0.000000    14.454200
# ...

# %%
df.loc[1,'name']
# Out:
# 'Allison, Master. Hudson Trevor'

# %%
df.iloc[::2,::3]
# Out:
#       pclass   age  ticket embarked
# 0          1  29.0   24160        S
# 2          1   2.0  113781        S
# 4          1  25.0  113781        S
# 6          1  63.0   13502        S
# 8          1  53.0   11769        S
# ...      ...   ...     ...      ...
# 1300       3  15.0    2659        C
# 1302       3   NaN    2647        C
# 1304       3  14.5    2665        C
# 1306       3  26.5    2656        C
# 1308       3  29.0  315082        S
#
# [655 rows x 4 columns]

# %%
df.head(-10)
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1294       3                             Williams, Mr. Leslie    male
# 1295       3                              Windelov, Mr. Einar    male
# 1296       3                                 Wirz, Mr. Albert    male
# 1297       3                           Wiseman, Mr. Phillippe    male
# 1298       3                        Wittevrongel, Mr. Camille    male
#
#           age  sibsp  parch            ticket      fare    cabin embarked  \
# ...

# %%
df.tail(-10)
# Out:
#       pclass                                               name     sex   age  \
# 10         1                             Astor, Col. John Jacob    male  47.0
# 11         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0
# 12         1                      Aubart, Mme. Leontine Pauline  female  24.0
# 13         1                       Barber, Miss. Ellen "Nellie"  female  26.0
# 14         1               Barkworth, Mr. Algernon Henry Wilson    male  80.0
# ...      ...                                                ...     ...   ...
# 1304       3                               Zabour, Miss. Hileni  female  14.5
# 1305       3                              Zabour, Miss. Thamine  female   NaN
# 1306       3                          Zakarian, Mr. Mapriededer    male  26.5
# 1307       3                                Zakarian, Mr. Ortin    male  27.0
# 1308       3                                 Zimmerman, Mr. Leo    male  29.0
#
# ...

# %% [markdown]
# # NULL FUNCTIONS
# isnull
# notnull

# %%
r1=df.isnull()
r2=df['cabin'].isnull()
r3=df[['cabin','age','sex']].isnull()
print(r1,r2,r3)
# Out:
#       pclass   name    sex    age  sibsp  parch  ticket   fare  cabin  \
# 0      False  False  False  False  False  False   False  False  False
# 1      False  False  False  False  False  False   False  False  False
# 2      False  False  False  False  False  False   False  False  False
# 3      False  False  False  False  False  False   False  False  False
# 4      False  False  False  False  False  False   False  False  False
# ...      ...    ...    ...    ...    ...    ...     ...    ...    ...
# 1304   False  False  False  False  False  False   False  False   True
# 1305   False  False  False   True  False  False   False  False   True
# 1306   False  False  False  False  False  False   False  False   True
# 1307   False  False  False  False  False  False   False  False   True
# 1308   False  False  False  False  False  False   False  False   True
#
#       embarked  survived
# 0        False     False
# 1        False     False
# 2        False     False
# ...

# %%
r4=df.notnull()
r5=df['cabin'].notnull()
r6=df[['cabin','age','sex']].notnull()
print(r4,r5,r6)
# Out:
#       pclass  name   sex    age  sibsp  parch  ticket  fare  cabin  embarked  \
# 0       True  True  True   True   True   True    True  True   True      True
# 1       True  True  True   True   True   True    True  True   True      True
# 2       True  True  True   True   True   True    True  True   True      True
# 3       True  True  True   True   True   True    True  True   True      True
# 4       True  True  True   True   True   True    True  True   True      True
# ...      ...   ...   ...    ...    ...    ...     ...   ...    ...       ...
# 1304    True  True  True   True   True   True    True  True  False      True
# 1305    True  True  True  False   True   True    True  True  False      True
# 1306    True  True  True   True   True   True    True  True  False      True
# 1307    True  True  True   True   True   True    True  True  False      True
# 1308    True  True  True   True   True   True    True  True  False      True
#
#       survived
# 0         True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# FILLER METHODS
# fillna--------------> ffill(),bfill()
# dropna

# %%
df['age'].fillna(29.881135,inplace=True)
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\4270620501.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(29.881135,inplace=True)

# %%
df['fare']=df['fare'].fillna(method='ffill')
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\3085147082.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['fare']=df['fare'].fillna(method='ffill')

# %%
df['embarked'].mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
df['embarked']=df['embarked'].fillna('S')

# %%
df=df.dropna(axis=1)

# %%
df['survived']=df['survived'].astype('Float64')
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\2539211074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['survived']=df['survived'].astype('Float64')

# %% [markdown]
# **feature engineering**

# %%
df["embarked"]=df["embarked"].replace({"S":"Southampton","C":"Cherbourg","Q":"Queenstown"})
df
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\4007948647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["embarked"]=df["embarked"].replace({"S":"Southampton","C":"Cherbourg","Q":"Queenstown"})
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# ...

# %%
df['family_count']=df['sibsp']+df['parch']
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket      fare     embarked  survived  \
# ...

# %%
df['name'].str.split(',',expand=True)
df['last_name']=df['name'].str.split(',',n=1,expand=True)[0]
df['title_fname']=df['name'].str.split(',',n=1,expand=True)[1]
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket      fare     embarked  survived  \
# ...

# %%
x,y=df['title_fname'].str.split('.',n=1,expand=True)
print(x)
print(y)
# Out:
# 0
# 1

# %%
df['title']=df['title_fname'].str.split('.',n=1,expand=True)[0]
df['first_name']=df['title_fname'].str.split('.',n=1,expand=True)[1]
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#             age  sibsp  parch  ticket      fare     embarked  survived  \
# ...

# %%
df.columns
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'embarked', 'survived', 'family_count', 'last_name', 'title_fname',
#        'title', 'first_name'],
#       dtype='object')

# %%
df.drop(columns=['sibsp','parch','name','title_fname'],inplace=True)

# %%
df.columns
# Out:
# Index(['pclass', 'sex', 'age', 'ticket', 'fare', 'embarked', 'survived',
#        'family_count', 'last_name', 'title', 'first_name'],
#       dtype='object')

# %%
new_order=df.columns[[9,10,8,1,2,7,3,0,4,5,6]]
df=df[new_order]

# %%
df
# Out:
#         title                          first_name  last_name     sex  \
# 0        Miss                    Elisabeth Walton      Allen  female
# 1      Master                       Hudson Trevor    Allison    male
# 2        Miss                       Helen Loraine    Allison  female
# 3          Mr             Hudson Joshua Creighton    Allison    male
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)    Allison  female
# ...       ...                                 ...        ...     ...
# 1304     Miss                              Hileni     Zabour  female
# 1305     Miss                             Thamine     Zabour  female
# 1306       Mr                         Mapriededer   Zakarian    male
# 1307       Mr                               Ortin   Zakarian    male
# 1308       Mr                                 Leo  Zimmerman    male
#
#             age  family_count  ticket  pclass      fare     embarked  survived
# ...

# %% [markdown]
# CUT()

# %%
df['age']=pd.cut(df['age'],bins=[0,15,30,59,100],labels=['childrens','teenager','adult','senior'])
df.rename(columns={'age':'age_group'},inplace=True)
# b=[0,15,30,59,100] l=['childrens','teenager','adult','senior'] and pass bins=b,labels=l
df
# Out:
#         title                          first_name  last_name     sex  \
# 0        Miss                    Elisabeth Walton      Allen  female
# 1      Master                       Hudson Trevor    Allison    male
# 2        Miss                       Helen Loraine    Allison  female
# 3          Mr             Hudson Joshua Creighton    Allison    male
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)    Allison  female
# ...       ...                                 ...        ...     ...
# 1304     Miss                              Hileni     Zabour  female
# 1305     Miss                             Thamine     Zabour  female
# 1306       Mr                         Mapriededer   Zakarian    male
# 1307       Mr                               Ortin   Zakarian    male
# 1308       Mr                                 Leo  Zimmerman    male
#
#       age_group  family_count  ticket  pclass      fare     embarked  survived
# ...

# %% [markdown]
# SORT_VALUES()

# %%
df.sort_values('last_name',inplace=True)
df
# Out:
#         title                      first_name      last_name     sex  \
# 600        Mr                         Anthony         Abbing    male
# 601    Master                   Eugene Joseph         Abbott    male
# 602        Mr                 Rossmore Edward         Abbott    male
# 603       Mrs             Stanton (Rosa Hunt)         Abbott  female
# 605        Mr                 Olaus Jorgensen       Abelseth    male
# ...       ...                             ...            ...     ...
# 392       Mrs   Sebastiano (Argenia Genovesi)      del Carlo  female
# 1264       Mr                   Austin Blyler   van Billiard    male
# 1263   Master                     Walter John   van Billiard    male
# 1262   Master                   James William   van Billiard    male
# 1268       Mr                        Philemon  van Melkebeke    male
#
#       age_group  family_count         ticket  pclass     fare     embarked  \
# ...

# %% [markdown]
# # GROUP BY AND AGGREGATE METHODS
# GROUPBY()
# GROUPS()
# GET_GROUPS()

# %%
gp_obj=df.groupby('age_group')
gp_obj.groups
gp_obj.get_group('adult')
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\3819423135.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gp_obj=df.groupby('age_group')
#      title                           first_name       last_name     sex  \
# 600     Mr                              Anthony          Abbing    male
# 603    Mrs                  Stanton (Rosa Hunt)          Abbott  female
# 610    Mrs   Johan (Johanna Persdotter Larsson)           Ahlin  female
# 618     Mr                        William Henry           Allen    male
# 620     Mr                        Albert Karvin        Andersen    male
# ...    ...                                  ...             ...     ...
# 1301    Mr                              Gerious         Youseff    male
# ...

# %%
gp_obj=df.groupby(['age_group','sex'])
gp_obj.groups
gp_obj.get_group(('adult','male'))
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\989917425.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gp_obj=df.groupby(['age_group','sex'])
#      title         first_name       last_name   sex age_group  family_count  \
# 600     Mr            Anthony          Abbing  male     adult             0
# 618     Mr      William Henry           Allen  male     adult             0
# 620     Mr      Albert Karvin        Andersen  male     adult             0
# 5       Mr              Harry        Anderson  male     adult             0
# 629     Mr       Anders Johan       Andersson  male     adult             6
# ...    ...                ...             ...   ...       ...           ...
# 1298    Mr            Camille    Wittevrongel  male     adult             0
# ...

# %% [markdown]
# # AGGREGATE METHODS
# COUNT()
# MAX()
# MIN()
# SUM()
# MEAN()

# %% [markdown]
# COUNT()

# %%
df['embarked'].count()
# Out:
# np.int64(1309)

# %%
grp_obj=df.groupby('embarked')
grp_obj.count()
# Out:
#              title  first_name  last_name  sex  age_group  family_count  \
# embarked
# Cherbourg      270         270        270  270        270           270
# Queenstown     123         123        123  123        123           123
# Southampton    916         916        916  916        916           916
#
#              ticket  pclass  fare  survived
# embarked
# Cherbourg       270     270   270       270
# Queenstown      123     123   123       123
# Southampton     916     916   916       916

# %%
grp_obj['age_group'].count()
# Out:
# embarked
# Cherbourg      270
# Queenstown     123
# Southampton    916
# Name: age_group, dtype: int64

# %% [markdown]
# MAX()

# %%
df['embarked'].max()
# Out:
# 'Southampton'

# %%
df['fare'].max()
# Out:
# np.float64(512.3292)

# %%
grp_obj=df.groupby('embarked')
grp_obj.max()
grp_obj['fare'].max()
# Out:
# embarked
# Cherbourg      512.3292
# Queenstown      90.0000
# Southampton    263.0000
# Name: fare, dtype: float64

# %% [markdown]
# MIN()

# %%
df['embarked'].min()
# Out:
# 'Cherbourg'

# %%
df['fare'].min()
# Out:
# np.float64(0.0)

# %%
grp_obj=df.groupby('embarked')
grp_obj.min()
grp_obj['fare'].min()
# Out:
# embarked
# Cherbourg      4.0125
# Queenstown     6.7500
# Southampton    0.0000
# Name: fare, dtype: float64

# %% [markdown]
# SUM()

# %%
df['embarked'].sum()
# Out:
# '...'

# %%
df['fare'].sum()
# Out:
# np.float64(43558.5369)

# %%
grp_obj=df.groupby('embarked')
grp_obj.sum(numeric_only=True)
# Out:
#              family_count  pclass        fare  survived
# embarked
# Cherbourg             208     500  16830.7922     150.0
# Queenstown             56     356   1526.3085      44.0
# Southampton           893    2148  25201.4362     306.0

# %%
grp_obj['fare'].sum()# When we pass the column with the numeric datatype then numeric_only is not required
# Out:
# embarked
# Cherbourg      16830.7922
# Queenstown      1526.3085
# Southampton    25201.4362
# Name: fare, dtype: float64

# %% [markdown]
# MEAN()

# %%
#df['embarked'].mean()# error
df['fare'].mean()
# Out:
# np.float64(33.27619320091673)

# %%
grp_obj=df.groupby('embarked')
grp_obj.mean(numeric_only=True)
# Out:
#              family_count    pclass       fare  survived
# embarked
# Cherbourg        0.770370  1.851852  62.336267  0.555556
# Queenstown       0.455285  2.894309  12.409012  0.357724
# Southampton      0.974891  2.344978  27.512485  0.334061

# %%
grp_obj['fare'].mean()
# Out:
# embarked
# Cherbourg      62.336267
# Queenstown     12.409012
# Southampton    27.512485
# Name: fare, dtype: float64

# %% [markdown]
# AGG()

# %%
df.agg({'age_group':['max','count'],
        'fare':['sum','count','mean']})
# Out:
#       age_group          fare
# max      senior           NaN
# count      1309   1309.000000
# sum         NaN  43558.536900
# mean        NaN     33.276193

# %%
# df['fare'].agg([sum,max]) # to avoid future warning pass mrf in string format.
df['fare'].agg(['sum','max'])
# Out:
# sum    43558.5369
# max      512.3292
# Name: fare, dtype: float64

# %% [markdown]
# value_counts()

# %%
g=df.groupby('sex')# here we need to write 2 lines so we go for value_counts()
g['sex'].count()
# Out:
# sex
# female    466
# male      843
# Name: sex, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %% [markdown]
# unique()

# %%
pd.unique(df['embarked'])
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown'], dtype=object)

# %% [markdown]
# pivot_table()

# %%
pd.pivot_table(data=df,values='fare',aggfunc=['sum'],columns='sex',index='pclass')
# Out:
#                sum
# sex         female        male
# pclass
# 1       15755.3834  12510.0209
# 2        2462.8917   3403.7457
# 3        3310.0379   6116.4573

# %%
pd.pivot_table(data=df,values='fare',aggfunc=['sum'],index='pclass')#either index or column should be there otherwise we get errror
# Out:
#                sum
#               fare
# pclass
# 1       28265.4043
# 2        5866.6374
# 3        9426.4952

# %%
pd.pivot_table(data=df,values='fare',aggfunc=['sum','mean'],columns='sex',index='pclass')
# Out:
#                sum                    mean
# sex         female        male      female       male
# pclass
# 1       15755.3834  12510.0209  109.412385  69.888385
# 2        2462.8917   3403.7457   23.234827  19.904946
# 3        3310.0379   6116.4573   15.324250  12.406607

# %%
pd.pivot_table(data=df,values='fare',aggfunc=['sum'],columns='pclass') # columns and index are for orientation purpose
# Out:
#                sum
# pclass           1          2          3
# fare    28265.4043  5866.6374  9426.4952

# %%
pd.pivot_table(data=df,values='fare',aggfunc=['sum'],index='embarked',columns='pclass')
# Out:
#                     sum
# pclass                1          2          3
# embarked
# Cherbourg    15065.1916   652.4166  1113.1840
# Queenstown     270.0000    82.1458  1174.1627
# Southampton  12930.2127  5132.0750  7139.1485

# %%
pd.pivot_table(data=df,values=['fare','age_group'],aggfunc=['max'],index='embarked',columns='pclass')
# Out:
#                   max
#             age_group                      fare
# pclass              1       2       3         1        2        3
# embarked
# Cherbourg      senior   adult   adult  512.3292  41.5792  22.3583
# Queenstown      adult  senior  senior   90.0000  12.3500  29.1250
# Southampton    senior  senior  senior  263.0000  73.5000  69.5500

# %%
pd.pivot_table(data=df,values=['fare','survived'],aggfunc=['sum','max'],index='embarked',columns='pclass')
# Out:
#                     sum                                               \
#                    fare                       survived
# pclass                1          2          3        1      2      3
# embarked
# Cherbourg    15065.1916   652.4166  1113.1840     97.0   16.0   37.0
# Queenstown     270.0000    82.1458  1174.1627      2.0    2.0   40.0
# Southampton  12930.2127  5132.0750  7139.1485    101.0  101.0  104.0
#
#                   max
#                  fare                   survived
# pclass              1        2        3        1    2    3
# embarked
# Cherbourg    512.3292  41.5792  22.3583      1.0  1.0  1.0
# Queenstown    90.0000  12.3500  29.1250      1.0  1.0  1.0
# Southampton  263.0000  73.5000  69.5500      1.0  1.0  1.0

# %%
pd.pivot_table(data=df,values=['fare'],aggfunc=['max','sum'],index=['sex','embarked'],columns='pclass')
# Out:
#                          max                          sum             \
#                         fare                         fare
# pclass                     1        2        3          1          2
# sex    embarked
# female Cherbourg    512.3292  41.5792  22.3583  8441.6124   297.0417
#        Queenstown    90.0000  12.3500  29.1250   180.0000    24.7000
#        Southampton  263.0000  65.0000  69.5500  7133.7710  2141.1500
# male   Cherbourg    512.3292  41.5792  22.3583  6623.5792   355.3749
#        Queenstown    90.0000  12.3500  29.1250    90.0000    57.4458
#        Southampton  263.0000  73.5000  69.5500  5796.4417  2990.9250
#
#
#
# pclass                      3
# sex    embarked
# female Cherbourg     428.8709
#        Queenstown    548.3502
#        Southampton  2332.8168
# male   Cherbourg     684.3131
#        Queenstown    625.8125
#        Southampton  4806.3317

# %% [markdown]
# CORR()

# %%
df.corr(numeric_only=True)
# Out:
#               family_count    pclass      fare  survived
# family_count      1.000000  0.050027  0.226653  0.026876
# pclass            0.050027  1.000000 -0.558740 -0.312469
# fare              0.226653 -0.558740  1.000000  0.244479
# survived          0.026876 -0.312469  0.244479  1.000000

# %%
df['sex']=df['sex'].map({'female':0,'male':1})

# %%
pd.unique(df['embarked'])
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown'], dtype=object)

# %%
df['embarked']=df['embarked'].map({'Cherbourg':0,'Queenstown':1,'Southampton':2})

# %%
pd.unique(df['age_group'])
# Out:
# ['adult', 'childrens', 'teenager', 'senior']
# Categories (4, object): ['childrens' < 'teenager' < 'adult' < 'senior']

# %%
df
# Out:
#         title                      first_name      last_name  sex  age_group  \
# 600        Mr                         Anthony         Abbing    1      adult
# 601    Master                   Eugene Joseph         Abbott    1  childrens
# 602        Mr                 Rossmore Edward         Abbott    1   teenager
# 603       Mrs             Stanton (Rosa Hunt)         Abbott    0      adult
# 605        Mr                 Olaus Jorgensen       Abelseth    1   teenager
# ...       ...                             ...            ...  ...        ...
# 392       Mrs   Sebastiano (Argenia Genovesi)      del Carlo    0   teenager
# 1264       Mr                   Austin Blyler   van Billiard    1      adult
# 1263   Master                     Walter John   van Billiard    1  childrens
# 1262   Master                   James William   van Billiard    1   teenager
# 1268       Mr                        Philemon  van Melkebeke    1   teenager
#
# ...

# %%
df['age_group']=df['age_group'].map({'adult':0,'childrens':1,'senior':2,'teenager':3})
df
# Out:
#         title                      first_name      last_name  sex age_group  \
# 600        Mr                         Anthony         Abbing    1         0
# 601    Master                   Eugene Joseph         Abbott    1         1
# 602        Mr                 Rossmore Edward         Abbott    1         3
# 603       Mrs             Stanton (Rosa Hunt)         Abbott    0         0
# 605        Mr                 Olaus Jorgensen       Abelseth    1         3
# ...       ...                             ...            ...  ...       ...
# 392       Mrs   Sebastiano (Argenia Genovesi)      del Carlo    0         3
# 1264       Mr                   Austin Blyler   van Billiard    1         0
# 1263   Master                     Walter John   van Billiard    1         1
# 1262   Master                   James William   van Billiard    1         3
# 1268       Mr                        Philemon  van Melkebeke    1         3
#
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                    sex  family_count    pclass      fare  embarked  survived
# sex           1.000000     -0.188583  0.124617 -0.185744  0.097960 -0.528693
# family_count -0.188583      1.000000  0.050027  0.226653  0.067598  0.026876
# pclass        0.124617      0.050027  1.000000 -0.558740  0.185479 -0.312469
# fare         -0.185744      0.226653 -0.558740  1.000000 -0.238181  0.244479
# embarked      0.097960      0.067598  0.185479 -0.238181  1.000000 -0.175313
# survived     -0.528693      0.026876 -0.312469  0.244479 -0.175313  1.000000

# %%
df['pclass'].corr(df['fare'])
# Out:
# np.float64(-0.5587404879593056)

# %% [markdown]
# 1. get the no_of_passengers
# 2. get the passengers title and f_name as one column
# 3. get the unique titles
# 4. get the unique survival
# 5. get only female passengers f_name and fare
# 6. get only childers and senior passengers name
# 7. check the corelation of fare and survival.
# 8. get no_of_families
# 9. get the gender wise survival rate
# 10. get the pclass wise survival rate

# %% [markdown]
# 1. get the no_of_passengers

# %%
df.shape[0]

# len()  df['pclass].count()
# Out:
# 1309

# %%
df.columns
# Out:
# Index(['title', 'first_name', 'last_name', 'sex', 'age_group', 'family_count',
#        'ticket', 'pclass', 'fare', 'embarked', 'survived'],
#       dtype='object')

# %% [markdown]
# 2. get the passengers title and f_name as one column

# %%
df['title']+'.'+df['first_name']
# Out:
# 600                             Mr. Anthony
# 601                   Master. Eugene Joseph
# 602                     Mr. Rossmore Edward
# 603                Mrs. Stanton (Rosa Hunt)
# 605                     Mr. Olaus Jorgensen
#                        ...
# 392      Mrs. Sebastiano (Argenia Genovesi)
# 1264                      Mr. Austin Blyler
# 1263                    Master. Walter John
# 1262                  Master. James William
# 1268                           Mr. Philemon
# Length: 1309, dtype: object

# %% [markdown]
# 3. get the unique titles

# %%
pd.unique(df['title'])
# Out:
# array([' Mr', ' Master', ' Mrs', ' Miss', ' Col', ' Mme', ' Rev', ' Dr',
#        ' Major', ' Capt', ' Sir', ' Lady', ' Mlle', ' Ms', ' Dona',
#        ' Jonkheer', ' the Countess', ' Don'], dtype=object)

# %% [markdown]
# 4. get the unique survival

# %%
pd.unique(df['survived'])
# Out:
# <FloatingArray>
# [0.0, 1.0]
# Length: 2, dtype: Float64

# %% [markdown]
# observation :

# %% [markdown]
# 5. get only female passengers f_name and fare

# %%
f_passenger=df[df['sex']==0]
f_passenger[['first_name','fare']]
# Out:
#                                first_name     fare
# 603                   Stanton (Rosa Hunt)  20.2500
# 604                           Karen Marie   7.6500
# 324               Samuel (Hannah Wizosky)  24.0000
# 607           Joseph (Sophie Halaut Easu)   7.2292
# 610    Johan (Johanna Persdotter Larsson)   9.4750
# ...                                   ...      ...
# 599             Henriette ("Mrs Harbeck")  13.0000
# 1304                               Hileni  14.4542
# 1305                              Thamine  14.4542
# 759               Guillaume Joseph (Emma)  17.4000
# 392         Sebastiano (Argenia Genovesi)  27.7208
#
# [466 rows x 2 columns]

# %%
grp_obj=df.groupby('sex')
grp_obj.groups
# Out:
# {0: [603, 604, 324, 607, 610, 612, 0, 4, 2, 621, 623, 624, 625, 626, 628, 627, 632, 6, 329, 8, 636, 643, 646, 647, 11, 650, 12, 653, 656, 657, 658, 659, 660, 661, 333, 665, 666, 13, 667, 17, 18, 337, 340, 341, 342, 21, 344, 23, 24, 27, 28, 32, 33, 679, 681, 682, 684, 35, 36, 686, 687, 352, 350, 349, 41, 42, 353, 692, 43, 44, 695, 355, 358, 697, 696, 361, 362, 702, 48, 706, 50, 710, 709, 365, 57, 55, 59, 61, 63, 65, 369, 66, 67, 69, 370, 371, 72, 373, 73, 377, ...], 1: [600, 601, 602, 605, 323, 606, 608, 609, 611, 613, 325, 614, 615, 616, 617, 618, 1, 3, 619, 620, 5, 629, 622, 630, 631, 633, 327, 326, 7, 634, 328, 635, 637, 9, 330, 638, 642, 641, 640, 639, 645, 644, 648, 649, 10, 651, 652, 654, 655, 662, 331, 332, 663, 334, 664, 14, 668, 335, 15, 16, 336, 19, 338, 669, 339, 20, 343, 22, 670, 671, 345, 673, 672, 674, 675, 25, 26, 676, 29, 30, 31, 34, 677, 346, 678, 680, 683, 685, 347, 348, 37, 38, 39, 688, 689, 40, 690, 691, 351, 354, ...]}

# %%
grp_obj.get_group(0)[['first_name','fare']]
# Out:
#                                first_name     fare
# 603                   Stanton (Rosa Hunt)  20.2500
# 604                           Karen Marie   7.6500
# 324               Samuel (Hannah Wizosky)  24.0000
# 607           Joseph (Sophie Halaut Easu)   7.2292
# 610    Johan (Johanna Persdotter Larsson)   9.4750
# ...                                   ...      ...
# 599             Henriette ("Mrs Harbeck")  13.0000
# 1304                               Hileni  14.4542
# 1305                              Thamine  14.4542
# 759               Guillaume Joseph (Emma)  17.4000
# 392         Sebastiano (Argenia Genovesi)  27.7208
#
# [466 rows x 2 columns]

# %% [markdown]
# 6. get only childerns and senior passengers name

# %%
grp_obj=df.groupby('age_group')
grp_obj.groups
g1=grp_obj.get_group(1)['first_name']
g2=grp_obj.get_group(2)['first_name']
print(g1,g2)
# Out:
# 601                  Eugene Joseph
# 611                   Philip Frank
# 1                    Hudson Trevor
# 2                    Helen Loraine
# 622           Sigvard Harald Elias
#                    ...
# 590                      Barbara J
# 591               Constance Mirium
# 1300     Antoni (Selini Alexander)
# 1304                        Hileni
# 1263                   Walter John
# Name: first_name, Length: 115, dtype: object 6                                   Kornelia Theodosia
# 9                                                Ramon
# 14                               Algernon Henry Wilson
# 351                             Thomas William Solomon
# 43                    William Robert (Emma Eliza Ward)
# 61              Tyrell William (Julia Florence Siegel)
# 78             Alexander Taylor (Mary Eliza Ingersoll)
# 727                                            Patrick
# 81                                      Edward Gifford
# ...

# %%
# grp_obj=df.groupby('age_group')
# grp_obj.groups
# grp_obj.get_group((1,2))['first_name']
# # grp_obj.get_group(2)['first_name']
# # print(g1,g2)

# %% [markdown]
# 7. check the corelation of fare and survival.

# %%
df.columns
# Out:
# Index(['title', 'first_name', 'last_name', 'sex', 'age_group', 'family_count',
#        'ticket', 'pclass', 'fare', 'embarked', 'survived'],
#       dtype='object')

# %%
df['fare'].corr(df['survived'])
# Out:
# np.float64(0.24447867975610565)

# %% [markdown]
# 8. get no_of_families

# %%
pd.unique(df['last_name'])
# Out:
# array(['Abbing', 'Abbott', 'Abelseth', 'Abelson', 'Abrahamsson',
#        'Abrahim', 'Adahl', 'Adams', 'Ahlin', 'Aks', 'Albimona',
#        'Aldworth', 'Alexander', 'Alhomaki', 'Ali', 'Allen', 'Allison',
#        'Allum', 'Andersen', 'Andersen-Jensen', 'Anderson', 'Andersson',
#        'Andreasson', 'Andrew', 'Andrews', 'Angheloff', 'Angle',
#        'Appleton', 'Arnold-Franchi', 'Aronsson', 'Artagaveytia', 'Ashby',
#        'Asim', 'Asplund', 'Assaf', 'Assaf Khalil', 'Assam', 'Astor',
#        'Attalah', 'Aubart', 'Augustsson', 'Ayoub', 'Baccos', 'Backstrom',
#        'Baclini', 'Badman', 'Badt', 'Bailey', 'Baimbrigge', 'Balkic',
#        'Ball', 'Banfield', 'Barah', 'Barbara', 'Barber', 'Barkworth',
#        'Barry', 'Barton', 'Bateman', 'Baumann', 'Baxter', 'Bazzani',
#        'Beane', 'Beattie', 'Beauchamp', 'Beavan', 'Becker', 'Beckwith',
#        'Beesley', 'Behr', 'Bengtsson', 'Bentham', 'Berglund', 'Berriman',
# ...

# %%
df['last_name'].count()
# Out:
# np.int64(1309)

# %% [markdown]
# 9. get the gender wise survival rate

# %%
grp_obj=df.groupby(['sex','survived'])
grp_obj.groups
# Out:
# {(0, 0.0): [610, 4, 2, 623, 624, 626, 628, 627, 632, 636, 650, 665, 666, 667, 679, 681, 682, 684, 687, 692, 695, 697, 696, 702, 706, 710, 365, 369, 726, 381, 382, 743, 749, 779, 105, 800, 806, 811, 807, 411, 832, 829, 828, 840, 841, 852, 859, 861, 864, 865, 445, 456, 877, 878, 169, 901, 903, 907, 908, 468, 928, 932, 937, 939, 475, 943, 957, 958, 956, 955, 961, 966, 967, 969, 975, 490, 987, 992, 1008, 1011, 1012, 1013, 1014, 1054, 1058, 1076, 1095, 1086, 1091, 1090, 1099, 1100, 1098, 1106, 1112, 1113, 1124, 1126, 1130, 1136, ...], (0, 1.0): [603, 604, 324, 607, 612, 0, 621, 625, 6, 329, 8, 643, 646, 647, 11, 12, 653, 656, 657, 658, 659, 660, 661, 333, 13, 17, 18, 337, 340, 341, 342, 21, 344, 23, 24, 27, 28, 32, 33, 35, 36, 686, 352, 350, 349, 41, 42, 353, 43, 44, 355, 358, 361, 362, 48, 50, 709, 57, 55, 59, 61, 63, 65, 66, 67, 69, 370, 371, 72, 373, 73, 377, 379, 76, 78, 725, 380, 79, 735, 738, 82, 83, 85, 745, 88, 90, 387, 388, 757, 763, 765, 771, 92, 95, 396, 395, 97, 98, 778, 780, 
# ...

# %%
grp_obj.count()
# Out:
#               title  first_name  last_name  age_group  family_count  ticket  \
# sex survived
# 0   0.0         127         127        127        127           127     127
#     1.0         339         339        339        339           339     339
# 1   0.0         682         682        682        682           682     682
#     1.0         161         161        161        161           161     161
#
#               pclass  fare  embarked
# sex survived
# 0   0.0          127   127       127
#     1.0          339   339       339
# 1   0.0          682   682       682
#     1.0          161   161       161

# %% [markdown]
# 10. get the pclass wise survival rate

# %%
gp_obj=df.groupby(['pclass','survived'])
gp_obj.groups
# Out:
# {(1, 0.0): [4, 3, 2, 7, 9, 10, 15, 16, 19, 25, 30, 34, 38, 39, 40, 45, 46, 51, 52, 53, 58, 60, 62, 70, 71, 74, 75, 77, 80, 81, 84, 89, 96, 101, 105, 106, 110, 115, 114, 118, 125, 126, 128, 132, 135, 138, 142, 147, 148, 150, 154, 156, 157, 158, 162, 166, 169, 171, 172, 173, 174, 175, 179, 184, 185, 189, 191, 194, 197, 200, 201, 203, 205, 206, 210, 211, 212, 215, 217, 221, 222, 223, 224, 225, 226, 228, 232, 234, 236, 237, 239, 241, 243, 244, 246, 248, 252, 262, 266, 268, ...], (1, 1.0): [0, 1, 5, 6, 8, 11, 12, 13, 14, 17, 18, 20, 21, 22, 23, 24, 27, 26, 28, 29, 31, 32, 33, 35, 36, 37, 41, 42, 43, 44, 47, 48, 50, 49, 57, 56, 55, 54, 59, 61, 63, 64, 65, 66, 67, 68, 69, 72, 73, 76, 78, 79, 82, 83, 85, 86, 87, 88, 90, 92, 91, 93, 94, 95, 97, 98, 100, 99, 102, 103, 104, 107, 108, 109, 112, 111, 116, 113, 117, 119, 120, 121, 122, 124, 123, 127, 129, 131, 130, 133, 134, 136, 139, 137, 141, 140, 144, 143, 146, 145, ...], (2, 0.0): [323, 325, 327, 326, 328, 330, 331, 332, 334, 335, 338, 345, 34
# ...

# %%
gp_obj.count()
# Out:
#                  title  first_name  last_name  sex  age_group  family_count  \
# pclass survived
# 1      0.0         123         123        123  123        123           123
#        1.0         200         200        200  200        200           200
# 2      0.0         158         158        158  158        158           158
#        1.0         119         119        119  119        119           119
# 3      0.0         528         528        528  528        528           528
#        1.0         181         181        181  181        181           181
#
#                  ticket  fare  embarked
# pclass survived
# 1      0.0          123   123       123
#        1.0          200   200       200
# 2      0.0          158   158       158
#        1.0          119   119       119
# 3      0.0          528   528       528
#        1.0          181   181       181

# %% [markdown]
# 11. on which are features survival is dependent.
# 12. which age_group has more survival rate.
# 13. does embarked feature has any effect on survival.
# 14. how many passengers were travelling and how many got survived.
# 15. how many male passengers were survived in pclass 1
# 16. is there any relation between pclass and fare features.
# 17. which passenger class has more survival chance and why.
# 18. get age_group wise total_fare and survival_count.
# 19. get gender and age_group wise survival rate.
# 20. get the count of passengers wrt their age_group and gender.
# 21. which age group passengers have less survival rate and why? is there any factor which affects the age_group.

# %% [markdown]
# 11. on which are features survival is dependent

# %%
df.corr(numeric_only=True)
# here survival feature is dependent on sex and pclass
# where survived is inversely proportional to the sex with moderate ralation and inversly proportional to the pclass .
# Out:
#                    sex  family_count    pclass      fare  embarked  survived
# sex           1.000000     -0.188583  0.124617 -0.185744  0.097960 -0.528693
# family_count -0.188583      1.000000  0.050027  0.226653  0.067598  0.026876
# pclass        0.124617      0.050027  1.000000 -0.558740  0.185479 -0.312469
# fare         -0.185744      0.226653 -0.558740  1.000000 -0.238181  0.244479
# embarked      0.097960      0.067598  0.185479 -0.238181  1.000000 -0.175313
# survived     -0.528693      0.026876 -0.312469  0.244479 -0.175313  1.000000

# %% [markdown]
# 12. which age_group has more survival rate.

# %%
df['age_group'].corr(df['survived'])
# Out:
# np.float64(-0.10007562632492681)

# %%
gp_obj=df.groupby(['age_group','survived'])
gp_obj.groups
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\2489382423.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   gp_obj=df.groupby(['age_group','survived'])
# ...

# %%
d=gp_obj.count()

# %%
# d['survived'].max()

# %%
d = pd.pivot_table(data=df,values='survived',aggfunc=['mean'],columns='age_group')
d.max()
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\2787367791.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   d = pd.pivot_table(data=df,values='survived',aggfunc=['mean'],columns='age_group')
#       age_group
# mean  1            0.573913
#       3            0.336856
#       0            0.420655
#       2                 0.3
# dtype: Float64

# %%
survival_rate=df.groupby('age_group')['survived'].mean()
survival_rate
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\3524522090.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_rate=df.groupby('age_group')['survived'].mean()
# age_group
# 1    0.573913
# 3    0.336856
# 0    0.420655
# 2         0.3
# Name: survived, dtype: Float64

# %%
survival_rate.max()
# Out:
# np.float64(0.5739130434782609)

# %% [markdown]
# 13. does embarked feature has any effect on survival.

# %%
df.corr(numeric_only=True)
# Out:
#                    sex  family_count    pclass      fare  embarked  survived
# sex           1.000000     -0.188583  0.124617 -0.185744  0.097960 -0.528693
# family_count -0.188583      1.000000  0.050027  0.226653  0.067598  0.026876
# pclass        0.124617      0.050027  1.000000 -0.558740  0.185479 -0.312469
# fare         -0.185744      0.226653 -0.558740  1.000000 -0.238181  0.244479
# embarked      0.097960      0.067598  0.185479 -0.238181  1.000000 -0.175313
# survived     -0.528693      0.026876 -0.312469  0.244479 -0.175313  1.000000

# %%
df['embarked'].corr(df['survived']) #no very weak relation it is negligible.
# Out:
# np.float64(-0.17531311143954098)

# %% [markdown]
# 14. how many passengers were travelling and how many got survived.

# %%
len(df['survived'])# no of passengers were travelled
# Out:
# 1309

# %%
df['survived'].sum() # no of passengers got survived.
# Out:
# np.float64(500.0)

# %% [markdown]
# 15. how many male passengers were survived in pclass 1

# %%
m_pass = df[(df['sex']==1) & (df['pclass']==1)]
m_pass
# Out:
#        title                first_name         last_name  sex age_group  \
# 1     Master             Hudson Trevor           Allison    1         1
# 3         Mr   Hudson Joshua Creighton           Allison    1         3
# 5         Mr                     Harry          Anderson    1         0
# 7         Mr                 Thomas Jr           Andrews    1         0
# 9         Mr                     Ramon      Artagaveytia    1         2
# ..       ...                       ...               ...  ...       ...
# 317       Mr         Richard Norris II          Williams    1         3
# 316       Mr             Charles Duane          Williams    1         0
# 318       Mr          Fletcher Fellows  Williams-Lambert    1         3
# 320       Mr                      Hugh           Woolner    1         3
# 321       Mr                    George            Wright    1         2
#
#      family_count    ticket  pclass      fare  embarked  survived
# ...

# %%
m_pass['survived'].sum()
# Out:
# np.float64(61.0)

# %%
grp_obj=df.groupby(['pclass','sex','survived'])
grp_obj

# %%
grp_obj.get_group((1,1,1)).count()
# Out:
# title           61
# first_name      61
# last_name       61
# sex             61
# age_group       61
# family_count    61
# ticket          61
# pclass          61
# fare            61
# embarked        61
# survived        61
# dtype: int64

# %% [markdown]
# 16. is there any relation between pclass and fare features

# %%
df['pclass'].corr(df['fare']) 
# yes there is an relationship
# pclass is inversly proportion to fare with moderate relation.
# Out:
# np.float64(-0.5587404879593056)

# %% [markdown]
# 17. which passenger class has more survival chance and why

# %%
survival_rate=df.groupby('pclass')['survived'].mean()
survival_rate
# Out:
# pclass
# 1    0.619195
# 2    0.429603
# 3    0.255289
# Name: survived, dtype: Float64

# %%
survival_rate.max()
# means pclass 1 has more survival chance.
# that may bcz they are paying more fare and so their survival probability is higher than other pclass.
# Out:
# np.float64(0.6191950464396285)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 600 to 1268
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1309 non-null   object
#  1   first_name    1309 non-null   object
#  2   last_name     1309 non-null   object
#  3   sex           1309 non-null   int64
#  4   age_group     1309 non-null   category
#  5   family_count  1309 non-null   int64
#  6   ticket        1309 non-null   object
#  7   pclass        1309 non-null   int64
#  8   fare          1309 non-null   float64
#  9   embarked      1309 non-null   int64
#  10  survived      1309 non-null   Float64
# dtypes: Float64(1), category(1), float64(1), int64(4), object(4)
# memory usage: 115.2+ KB

# %% [markdown]
# 18. get age_group wise total_fare and survival_count.

# %%
at1 =df.groupby('age_group')[['fare','survived']].mean()
at1
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\2639473952.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   at1 =df.groupby('age_group')[['fare','survived']].mean()
#                 fare  survived
# age_group
# 1          33.660471  0.573913
# 3          24.710997  0.336856
# 0          46.498919  0.420655
# 2          63.032190       0.3

# %% [markdown]
# 19. get gender and age_group wise survival rate.

# %%
df.groupby(['sex','age_group'],observed=False)['survived'].mean()
# Out:
# sex  age_group
# 0    1            0.660714
#      3            0.684825
#      0            0.823944
#      2            0.818182
# 1    1            0.491525
#      3               0.158
#      0            0.196078
#      2            0.103448
# Name: survived, dtype: Float64

# %%
df.groupby(['sex','age_group'])['survived'].mean()
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\3901704283.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['sex','age_group'])['survived'].mean()
# sex  age_group
# 0    1            0.660714
#      3            0.684825
#      0            0.823944
#      2            0.818182
# 1    1            0.491525
#      3               0.158
#      0            0.196078
#      2            0.103448
# Name: survived, dtype: Float64

# %% [markdown]
# 20. get the count of passengers wrt their age_group and gender.

# %%
df.groupby(['sex', 'age_group'])['survived'].count()
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\1035357998.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['sex', 'age_group'])['survived'].count()
# sex  age_group
# 0    1             56
#      3            257
#      0            142
#      2             11
# 1    1             59
#      3            500
#      0            255
#      2             29
# Name: survived, dtype: Int64

# %%
df.groupby(['sex','age_group']).count()
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\545762608.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['sex','age_group']).count()
#                title  first_name  last_name  family_count  ticket  pclass  \
# sex age_group
# 0   1             56          56         56            56      56      56
#     3            257         257        257           257     257     257
#     0            142         142        142           142     142     142
#     2             11          11         11            11      11      11
# 1   1             59          59         59            59      59      59
#     3            500         500        500           500     500     500
#     0            255         255        255           255     255     255
# ...

# %% [markdown]
# 21. which age group passengers have less survival rate and why? is there any factor which affects the age_group.

# %%
ds=df.groupby('age_group')['survived'].mean()
ds
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16932\1216682978.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ds=df.groupby('age_group')['survived'].mean()
# age_group
# 1    0.573913
# 3    0.336856
# 0    0.420655
# 2         0.3
# Name: survived, dtype: Float64

# %%
ds.min() # seniors age_group has less survival rate compare to others. it may because of theirs age.
# Out:
# np.float64(0.3)

# %%
df.corr(numeric_only=True)
# Out:
#                    sex  family_count    pclass      fare  embarked  survived
# sex           1.000000     -0.188583  0.124617 -0.185744  0.097960 -0.528693
# family_count -0.188583      1.000000  0.050027  0.226653  0.067598  0.026876
# pclass        0.124617      0.050027  1.000000 -0.558740  0.185479 -0.312469
# fare         -0.185744      0.226653 -0.558740  1.000000 -0.238181  0.244479
# embarked      0.097960      0.067598  0.185479 -0.238181  1.000000 -0.175313
# survived     -0.528693      0.026876 -0.312469  0.244479 -0.175313  1.000000

# %%
df
# Out:
#         title                      first_name      last_name  sex age_group  \
# 600        Mr                         Anthony         Abbing    1         0
# 601    Master                   Eugene Joseph         Abbott    1         1
# 602        Mr                 Rossmore Edward         Abbott    1         3
# 603       Mrs             Stanton (Rosa Hunt)         Abbott    0         0
# 605        Mr                 Olaus Jorgensen       Abelseth    1         3
# ...       ...                             ...            ...  ...       ...
# 392       Mrs   Sebastiano (Argenia Genovesi)      del Carlo    0         3
# 1264       Mr                   Austin Blyler   van Billiard    1         0
# 1263   Master                     Walter John   van Billiard    1         1
# 1262   Master                   James William   van Billiard    1         3
# 1268       Mr                        Philemon  van Melkebeke    1         3
#
# ...
