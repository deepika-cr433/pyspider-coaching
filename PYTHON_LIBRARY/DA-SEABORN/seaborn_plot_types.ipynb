# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import  seaborn as sns

# %%
df=pd.read_csv('titanic.csv')

# %%
df['age_groups']=pd.cut(df['age'],bins=[0,15,30,59,100],labels=['childrens','teenager','adult','senior'])
# df.rename(columns={'age':'age_group'},inplace=True)

# %%
df['age_groups']=df['age_groups'].map({'adult':0,'childrens':1,'senior':2,'teenager':3})

# %%
df
# Out:
#       Unnamed: 0    title                          first_name  last_name  \
# 0              0     Miss                    Elisabeth Walton      Allen
# 1              1   Master                       Hudson Trevor    Allison
# 2              2     Miss                       Helen Loraine    Allison
# 3              3       Mr             Hudson Joshua Creighton    Allison
# 4              4      Mrs   Hudson J C (Bessie Waldo Daniels)    Allison
# ...          ...      ...                                 ...        ...
# 1304        1304     Miss                              Hileni     Zabour
# 1305        1305     Miss                             Thamine     Zabour
# 1306        1306       Mr                         Mapriededer   Zakarian
# 1307        1307       Mr                               Ortin   Zakarian
# 1308        1308       Mr                                 Leo  Zimmerman
#
#          sex        age  family_count  ticket  pclass      fare     embarked  \
# ...

# %% [markdown]
# # UNIVARIATE PLOT
# countplot()
# kdeplot()
# histplot()

# %% [markdown]
# countplot()

# %%
plt.figure(figsize=(3,2))
sns.countplot(x='sex',data=df)
# sns.countplot(x='sex',data=df,hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# male passangers are more in number as compare to female passanger.

# %%
sns.countplot(x='sex',data=df,hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# --->more male passangers are travel in pclass 3 as compare to pclass 1 and pclass 2
# --->more female passangers are travel in pclass 3 as compare to pclass 1 and pclass 2

# %%
sns.countplot(x='sex',data=df,hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# survival rate is more in female passangers than the male passangers.

# %%
sns.countplot(x='sex',data=df,hue='fare')
plt.grid()

# %%
# sns.countplot(x='pclass',data=df)
sns.countplot(x='pclass',data=df,hue='survived')
# sns.countplot(x='pclass',data=df,hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %% [markdown]
# survival rate is more in pclass 1 as compare to pclass 3 and pclass 2.

# %%
sns.countplot(x='pclass',data=df,hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %% [markdown]
# most of the male and female passangers prefer travelling in pclass 3 as compare to pclass1 and pclass2.

# %%
# sns.countplot(x='age_group',data=df)
sns.countplot(x='age_groups',data=df,hue='survived')
# Out:
# <Axes: xlabel='age_groups', ylabel='count'>

# %%
sns.countplot(x='age_group',data=df,hue='pclass')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.countplot(x='age_group',data=df,hue='pclass')
#
# File c:\Users\Deepika C R\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#    2641     ax = plt.gca()
#
# ...

# %%
# sns.countplot(x='family_count',data=df)
sns.countplot(x='family_count',data=df,hue='survived')
# sns.countplot(x='family_count',data=df,hue='pclass')
# Out:
# <Axes: xlabel='family_count', ylabel='count'>

# %%
sns.countplot(x='family_count',data=df,hue='pclass')
# Out:
# <Axes: xlabel='family_count', ylabel='count'>

# %%
# sns.countplot(x='embarked',data=df)
sns.countplot(x='embarked',data=df,hue='pclass')
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
sns.countplot(x='sex',data=df,hue='pclass',palette=['blue','green','red'])
plt.grid()

# %%
sns.countplot(x='sex',data=df,hue='pclass',palette={1:'lightblue',2:'pink',3:'red'})
plt.grid()

# %%
sns.countplot(y='sex',data=df,hue='pclass',palette={1:'lightblue',2:'pink',3:'red'})
plt.grid()

# %%
sns.kdeplot(x='fare',data=df,fill=True,hue='sex')# default fill=False
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.kdeplot(x='fare',data=df,fill=True,hue='pclass')# default fill=False
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.kdeplot(x='fare',data=df,shade=True)
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16116\2053802566.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='fare',data=df,shade=True)
# <Axes: xlabel='fare', ylabel='Density'>

# %%
plt.figure(figsize=(20,6))
sns.kdeplot(x='fare',data=df,hue='sex',fill=True)
plt.xticks(np.arange(0,600,20))
# Out:
# ([<matplotlib.axis.XTick at 0x21a29a601d0>,
# ...
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100'),
#   Text(120, 0, '120'),
#   Text(140, 0, '140'),
#   Text(160, 0, '160'),
#   Text(180, 0, '180'),
#   Text(200, 0, '200'),
#   Text(220, 0, '220'),
#   Text(240, 0, '240'),
#   Text(260, 0, '260'),
#   Text(280, 0, '280'),
#   Text(300, 0, '300'),
#   Text(320, 0, '320'),
#   Text(340, 0, '340'),
#   Text(360, 0, '360'),
#   Text(380, 0, '380'),
#   Text(400, 0, '400'),
#   Text(420, 0, '420'),
#   Text(440, 0, '440'),
#   Text(460, 0, '460'),
#   Text(480, 0, '480'),
#   Text(500, 0, '500'),
#   Text(520, 0, '520'),
#   Text(540, 0, '540'),
#   Text(560, 0, '560'),
#   Text(580, 0, '580')])

# %%
# plt.figure(figsize=(40,10))
# sns.histplot(x='fare',data=df,bins=20,hue='survived')# bin ---> is to get the accurate amount of points to plot.
sns.histplot(x='fare',data=df,bins=20,hue='sex')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x='fare',data=df,bins=20)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
plt.figure(figsize=(40,10))
# sns.histplot(x='fare',data=df,bins=20,hue='age_group',palette='coolwarm')

# %%
plt.figure(figsize=(3,4))
sns.kdeplot(x='fare',data=df)
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.kdeplot(x='fare',data=df,shade=True,hue='sex')
# Out:
# C:\Users\Deepika C R\AppData\Local\Temp\ipykernel_16116\3160354981.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='fare',data=df,shade=True,hue='sex')
# <Axes: xlabel='fare', ylabel='Density'>

# %% [markdown]
# observation:
# fare amount are more likely to fall under the 10-20.
# bcz, probability density is high.
# (more datapoints can be found in 10-20)

# %%
sns.histplot(x='fare',data=df,bins=10,kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
plt.figure(figsize=(10,2))
sns.histplot(x='fare',data=df)
sns.histplot(x='fare',data=df,bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %% [markdown]
# observation:
# more datapoints(frequency is high,count,distribution) are present in the range of 10-20

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x='age',y='fare',data=df)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
plt.figure(figsize=(4,5))
sns.scatterplot(x='age',y='fare',data=df,hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
plt.figure(figsize=(1,0.3))
sns.jointplot(x='age',y='fare',data=df,hue='sex')

# %%
plt.figure(figsize=(1,0.3))
sns.jointplot(x='age',y='fare',data=df,hue='sex',kind="hist")

# %%
plt.figure(figsize=(1,0.3))
sns.jointplot(x='age',y='fare',data=df,kind="reg")

# %%
plt.figure(figsize=(1,0.3))
sns.jointplot(x='age',y='fare',data=df,kind="kde")

# %%
plt.figure(figsize=(1,0.3))
sns.jointplot(x='age',y='fare',data=df,kind='hex')

# %%
plt.figure(figsize=(2,2))
sns.barplot(x='pclass',y='fare',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.barplot(x='ticket',y='fare',data=df)
# Out:
# <Axes: xlabel='ticket', ylabel='fare'>

# %%
sns.barplot(x='pclass',y='fare',data=df,hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
plt.figure(figsize=(2,2))
sns.barplot(x='pclass',y='fare',data=df,estimator='mean') # estimator='max','min','var','std','sum','mean',(by default estimator='mean')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
plt.figure(figsize=(2,2))
sns.boxplot(data=df,x='pclass')
# Out:
# <Axes: xlabel='pclass'>

# %%
plt.figure(figsize=(7,2))
sns.boxplot(data=df,x='age')
# here due to present of more outliers at right side median is shifting towards the right than the left side.
# Out:
# <Axes: xlabel='age'>

# %%
plt.figure(figsize=(7,2))
sns.boxplot(data=df,x='pclass',y='age')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=df,x='sex',y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.lmplot(data=df,x='age',y='fare')# linear model plot

# %%
data=df[['fare','age','pclass']]
sns.pairplot(data)

# %%
data=df[['fare','age','pclass']]
sns.pairplot(data,hue='survived')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Deepika C R\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'survived'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 2
# ...

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='survived')

# %%
d=df.corr(numeric_only=True)
sns.heatmap(d)
# Out:
# <Axes: >

# %%
d=df[['age','fare','pclass','survived']].corr(numeric_only=True)
sns.heatmap(d)
# Out:
# <Axes: >

# %%
d=df[['age','fare','pclass','survived']].corr(numeric_only=True)
sns.heatmap(d,annot=True)
# Out:
# <Axes: >

# %%
d=df[['age','fare','pclass','survived']].corr(numeric_only=True)
sns.heatmap(d,annot=True,fmt='.3f')
# Out:
# <Axes: >

# %%
d=df[['age','fare','pclass','survived']].corr(numeric_only=True)
sns.heatmap(d,annot=True,fmt='.3f',cmap='Set3')
# Out:
# <Axes: >

# %%
fg=sns.FacetGrid(df,col='pclass',height=2)
fg.map(sns.histplot,'age')

# %%
fg=sns.FacetGrid(df,row='pclass',height=2)
fg.map(sns.histplot,'age')

# %%
fg=sns.FacetGrid(df,col='pclass',height=2.5,hue='sex')
fg.map(sns.kdeplot,'age')
fg.add_legend()
fg.set_titles(col_template='{col_name}')

# %%
fg=sns.FacetGrid(df,col='pclass',height=2.5,hue='sex')
fg.map(sns.histplot,'age')

# %%
fg=sns.FacetGrid(df,col='age_groups',height=2)
fg.map(sns.histplot,'fare')

# %%
d=[(df['age_groups']==0).sum(),(df['age_groups']==1).sum(),(df['age_groups']==2).sum(),(df['age_groups']==3).sum()]
plt.pie(d)
# Out:
# ([<matplotlib.patches.Wedge at 0x26894846e10>,
# ...
#  [Text(0.637345572558912, 0.8965437084378837, ''),
#   Text(-0.6308739626549893, 0.9011093403377812, ''),
#   Text(-0.915257802491502, 0.6101664977515784, ''),
#   Text(-0.26787825386667335, -1.0668838929824287, '')])

# %%
d=[(df['age_groups']==0).sum(),(df['age_groups']==1).sum(),(df['age_groups']==2).sum(),(df['age_groups']==3).sum()]
plt.pie(d,explode=[0.1,0,0,0],labels=['adult','child','senior','teen'],colors=['orange','red','blue','pink'])
# Out:
# ([<matplotlib.patches.Wedge at 0x268948acb90>,
# ...
#  [Text(0.6952860791551767, 0.9780476819322368, 'adult'),
#   Text(-0.6308739626549893, 0.9011093403377812, 'child'),
#   Text(-0.915257802491502, 0.6101664977515784, 'senior'),
#   Text(-0.26787825386667335, -1.0668838929824287, 'teen')])

# %%
d=[(df['age_groups']==0).sum(),(df['age_groups']==1).sum(),(df['age_groups']==2).sum(),(df['age_groups']==3).sum()]
plt.pie(d,explode=[0.1,0,0,0],labels=['adult','child','senior','teen'],colors=['orange','red','blue','pink'],shadow = True,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x268947f6030>,
# ...
#  [Text(-0.9780477123241568, 0.6952860364033523, 'adult'),
#   Text(-0.9011092375553547, -0.6308741094643271, 'child'),
#   Text(-0.6101663486371472, -0.9152579019002302, 'senior'),
#   Text(1.0668839366253218, -0.267878080049221, 'teen')])
