# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import  seaborn as sns

# %%
df=pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.size# no. of total vlues to th elements
# Out:
# 105684

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['date_added'] =  df['date_added'].fillna("Unknown")

# %%
df['country'].mode()
# Out:
# 0    United States
# Name: country, dtype: object

# %%
df['country'] =  df['country'].fillna("United States")

# %%
df['rating'] = df['rating'].ffill()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['duration']=df['duration'].fillna("0")

# %%
pd.unique(df['duration'])
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df['director']=df['director'].fillna("Unknown")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          7982 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['cast']=df['cast'].fillna("Unknown")

# %% [markdown]
# details of the shows where both directors name and cast is unknown.

# %%
df[(df['cast']=='Unknown') & (df["director"]=='Unknown')]
# Out:
#      show_id     type                                title director     cast  \
# 3         s4  TV Show                Jailbirds New Orleans  Unknown  Unknown
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia  Unknown  Unknown
# 14       s15  TV Show      Crime Stories: India Detectives  Unknown  Unknown
# 66       s67  TV Show        Raja Rasoi Aur Anya Kahaniyan  Unknown  Unknown
# 69       s70  TV Show       Stories by Rabindranath Tagore  Unknown  Unknown
# ...      ...      ...                                  ...      ...      ...
# 8605   s8606  TV Show                            Top Grier  Unknown  Unknown
# 8609   s8610  TV Show                               Towies  Unknown  Unknown
# 8700   s8701  TV Show                    Wartime Portraits  Unknown  Unknown
# 8755   s8756  TV Show                    Women Behind Bars  Unknown  Unknown
# 8803   s8804  TV Show                          Zombie Dumb  Unknown  Unknown
#
# ...

# %% [markdown]
# to find the details about the show title "house of cards"

# %%
df[df['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards  Unknown
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description  num_cast
# 1059  A ruthless politician will stop at nothing to ...        24

# %% [markdown]
# in which year highest number of the tv shows and movies were released? show with bar graph.

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1961       1
# 1925       1
# 1959       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %%
plt.figure(figsize=(12,6))
df['release_year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='release_year'>

# %% [markdown]
# how many movies & tv shows are in the dataset? show with bar graph

# %%
df.groupby("type").type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(x=df['type'])
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# to know all the movies released in year 2019

# %%
df[(df['type']=='Movie')&( df['release_year']==2019)]
# Out:
#      show_id   type                        title             director  \
# 90       s91  Movie               Paradise Hills     Alice Waddington
# 334     s335  Movie              Five Feet Apart       Justin Baldoni
# 348     s349  Movie                         Poms           Zara Hayes
# 378     s379  Movie              Fantastic Fungi   Louie Schwartzberg
# 389     s390  Movie                The Operative          Yuval Adler
# ...      ...    ...                          ...                  ...
# 8516   s8517  Movie    The Spy Who Fell to Earth      Thomas Meadmore
# 8631   s8632  Movie  Trixie Mattel: Moving Parts  Nicholas Zeig-Owens
# 8718   s8719  Movie       Westside vs. the World        Michael Fahey
# 8752   s8753  Movie                     Wish Man          Theo Davies
# 8756   s8757  Movie                    Woodstock        Barak Goodman
#
#                                                    cast  \
# 90    Emma Roberts, Danielle Macdonald, Awkwafina, E...
# ...

# %% [markdown]
# show only the titles of all TV shows that wwre released in india only

# %%
pd.unique(df['country'])
# Out:
# array(['United States', 'South Africa', 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
df[(df['type'] == 'TV Show') & (df['country'] == 'India')]
# Out:
#      show_id     type                               title director  \
# 4         s5  TV Show                        Kota Factory  Unknown
# 39       s40  TV Show                        Chhota Bheem  Unknown
# 50       s51  TV Show                       Dharmakshetra  Unknown
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan  Unknown
# 69       s70  TV Show      Stories by Rabindranath Tagore  Unknown
# ...      ...      ...                                 ...      ...
# 8173   s8174  TV Show                           Thackeray  Unknown
# 8235   s8236  TV Show                         The Calling    Bumpy
# 8321   s8322  TV Show  The Golden Years with Javed Akhtar  Unknown
# 8349   s8350  TV Show              The House That Made Me  Unknown
# 8775   s8776  TV Show                     Yeh Meri Family  Unknown
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# ...

# %%
df[(df['type'] == 'TV Show') & (df['country'] == 'India')] ['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %% [markdown]
# show top 10 directors, who gave the highest number of TV shows and movies to netflix?

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Unknown                   2634
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Martin Scorsese             12
# Youssef Chahine             12
# Jay Chapman                 12
# Name: count, dtype: int64

# %% [markdown]
# show all details of type movies and category mysteries or country united kingdom

# %%
df[(df['type']=='Movies') & (df['listed_in']=='TV mysteries') | (df['country']=='United States')]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 3         s4  TV Show             Jailbirds New Orleans
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# ...      ...      ...                               ...
# 8793   s8794    Movie              Yours, Mine and Ours
# 8802   s8803    Movie                            Zodiac
# 8803   s8804  TV Show                       Zombie Dumb
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 3                           Unknown
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# ...                             ...
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# What is the distribution of content ratings on Netflix?

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='rating', data=df)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %% [markdown]
# tvy===children
# tvg=== all general audiences including childern
# tvpg== parental guidance suggested.

# %% [markdown]
# What are the top 10 most frequent countries of origin for Netflix content?

# %%
plt.figure(figsize=(10,6))
tc = df['country'].value_counts().head(10)
sns.barplot(x=tc.index, y=tc.values)
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# What is the average duration of movies and TV shows on Netflix?

# %%
plt.figure(figsize=(6,20))
sns.boxplot(x='type', y='duration', data=df)
# Out:
# <Axes: xlabel='type', ylabel='duration'>

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                            Unknown  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Which actors appear in the most Netflix titles?

# %%
df['cast'].str.split(',').explode().value_counts()
# Out:
# cast
# Unknown              825
#  Anupam Kher          39
#  Rupa Bhimani         31
#  Takahiro Sakurai     30
#  Julie Tejwani        28
#                     ...
#  Birand Tunca          1
#  Atilla Kiliç          1
#  Saygin Asan           1
#  Emrah Girgin          1
# Michael Johnston       1
# Name: count, Length: 39297, dtype: int64

# %%
top_actors = df['cast'].str.split(',').explode().value_counts().head(10) 
sns.countplot(x=top_actors)
# Out:
# <Axes: xlabel='count', ylabel='count'>

# %% [markdown]
#  What is the distribution of content durations for movies?

# %%
plt.figure(figsize=(50,10))
movie_df = df[df['type'] == 'Movie']
sns.histplot(x='duration', data=movie_df)
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %% [markdown]
# What is the distribution of content durations for TV Shows?

# %%
plt.figure(figsize=(20,6))
tv_show_df = df[df['type'] == 'TV Show']
sns.histplot(x='duration', data=tv_show_df)
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %% [markdown]
# Which countries produce the most movies on Netflix?

# %%
plt.figure(figsize=(10,6))
movie_df = df[df['type'] == 'Movie'] 
country_counts = movie_df['country'].value_counts() 
sns.barplot(x=country_counts.index[:10], y=country_counts.values[:10])
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# Which countries produce the most TV shows on Netflix?

# %%
plt.figure(figsize=(10,6))
tv_show_df = df[df['type'] == 'TV Show'] 
country_counts = tv_show_df['country'].value_counts() 
sns.barplot(x=country_counts.index[:10], y=country_counts.values[:10])
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# What is the relationship between release year and content rating?

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='rating', y='release_year', data=df)
# Out:
# <Axes: xlabel='rating', ylabel='release_year'>

# %% [markdown]
# Which genres are most popular among movies?

# %%
plt.figure(figsize=(20,6))
from collections import Counter
movie_df = df[df['type'] == 'Movie'] 
all_genres = list(movie_df['listed_in'].str.split(',').explode()) 
top_genres = Counter(all_genres).most_common(10) 
sns.barplot(x=[genre[0] for genre in top_genres], y=[genre[1] for genre in top_genres])
# Out:
# <Axes: >

# %% [markdown]
# Which genres are most popular among TV shows?

# %%
plt.figure(figsize=(20,6))
tv_show_df = df[df['type'] == 'TV Show']
all_genres = list(tv_show_df['listed_in'].str.split(',').explode())
top_genres = Counter(all_genres).most_common(10)
sns.barplot(x=[genre[0] for genre in top_genres], y=[genre[1] for genre in top_genres])
# Out:
# <Axes: >

# %% [markdown]
# How does the number of cast members vary between movies and TV shows?

# %%
df['num_cast'] = df['cast'].str.split(',').str.len() 
sns.boxplot(x='type', y='num_cast', data=df)
# Out:
# <Axes: xlabel='type', ylabel='num_cast'>

# %% [markdown]
#  What is the relationship between the number of cast members and the duration of content?

# %%
plt.figure(figsize=(6,20))
sns.scatterplot(x='num_cast', y='duration', data=df)
# Out:
# <Axes: xlabel='num_cast', ylabel='duration'>

# %% [markdown]
# What is the distribution of content release years?

# %%
sns.histplot(x='release_year', data=df)
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>
